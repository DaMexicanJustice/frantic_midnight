# %%
# the following line is jupyter notebook specific 
# %matplotlib inline

# %%
import frantic_midnight as fm

url = "https://raw.githubusercontent.com/DaMexicanJustice/frantic_midnight/master/data%20sets/vgsales.csv"
filename = fm.download(url)

# %%
platforms = list(find_most_pop_platform_by_regions(filename).keys())
sales =  list(find_most_pop_platform_by_regions(filename).values())
plot_most_pop_platform_by_regions(platforms, sales)

# %%
countries = list(fm.find_sum_of_all(filename).keys())
bigSum = list(fm.find_sum_of_all(filename).values())
fm.plot_sum_of_all(countries, bigSum)

# %%
tt_labels = list( fm.genres2012(filename).keys() )
tt_values = list( fm.genres2012(filename).values() )
fm.plot_genres2012(tt_labels, tt_values)

# %%
tp_labels = list( fm.publisherWithMostTopHundred(filename).keys() )
tp_values = list( fm.publisherWithMostTopHundred(filename).values() )
fm.plot_top_publishers(tp_labels, tp_values)
